# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Old_Bikes_encoded.csv')

# %%
df
# Out:
#          price  kms_driven  owner  age  power  brand
# 0      35000.0     17654.0      1  3.0  110.0      0
# 1     119900.0     11000.0      1  4.0  350.0      1
# 2     600000.0       110.0      1  8.0  675.0      2
# 3      65000.0     16329.0      1  4.0  180.0      0
# 4      80000.0     10000.0      1  3.0  150.0      3
# ...        ...         ...    ...  ...    ...    ...
# 7319   25000.0     48587.0      1  8.0  150.0      5
# 7320   35000.0     60000.0      1  9.0  220.0      6
# 7321  450000.0      3430.0      1  4.0  750.0     14
# 7322  139000.0     21300.0      1  4.0  400.0      6
# 7323   80000.0      7127.0      1  5.0  220.0      6
#
# [7324 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['price'],axis = 1)
y = df['price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(x_train,y_train)
# Out:
# 0.9847110029015409

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
score
# Out:
# 0.9812264620011572

# %%
import joblib

# %%
joblib.dump(rf,'rf_model.joblib')
# Out:
# ['rf_model.joblib']

# %%
loaded_model = joblib.load('rf_model.joblib')

# %%
loaded_model.predict(x_test)
# Out:
# array([106405.16666667, 152134.        ,  52609.72857143,  30575.        ,
#         26030.        , 131271.6       ,  45287.        , 139020.        ,
#         26343.        ,  70300.        ,  46793.52777778,  21232.94      ,
#         50497.21      ,  44747.83333333,  43429.60666667, 162065.        ,
#        137180.24666667,  25472.5       ,  31390.        ,  39565.        ,
#         26404.        ,  12415.88666667,  59886.15      ,  74548.        ,
#        113000.75      , 427204.62      ,  36921.        , 109736.        ,
#        117338.28571429,  48312.53333333,  42273.41269841,  28383.5       ,
#         17660.78      ,  29366.42857143,  12430.04      ,  38212.97      ,
#        708561.        ,  42736.        , 115416.        ,  15774.        ,
#         66600.        ,  46189.36111111])
